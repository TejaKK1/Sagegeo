# %%
var('x1,x2,a,b')
eq1= x1+x2==a
eq2= x1-x2==b
show(solve((eq1,eq2),(x1,x2)))

# %%
f(x) == x**2+2*x+3
show(f(x))

# %%
f(2)

# %%
latex(f(x))

# %%
solve(f(x)==0,x)

# %%
show(f.roots())

# %%
var('x,y')
eq3= x**2+y**2==1
eq4= x*y==1/4
solve((eq3,eq4),(x,y))

# %%
solve(x^2-2*x+3>5,x)

# %%
var('x,y,a,b,c,d,e,f')
solve((a*x+b*y==c,d*x+e*y==f),(x,y))
