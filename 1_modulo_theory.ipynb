# %% [markdown]
# Fermat's theorem
#
# #p is a prime and relative primes (a,p) then (a**(p-1)) =cong= 1 (mod p)

# %%
(200**96)%97

# %%
gcd(97,100)

# %%
mod(100**(euler_phi(97)),97)

# %% [markdown]
# Willson's Theorem
#
# #p is any prime number only if ((p-1)!+1) =cong= 0 (mod p)

# %%
95.next_prime()

# %%
mod((factorial(96-1)+1),96)

# %%
mod((factorial(97-1)+1),97)
